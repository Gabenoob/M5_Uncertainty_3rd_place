# %%
import pandas as pd

# %%
pd.read_pickle('processed_data/grid_part_1_eval.pkl')
# Out:
#                                      id        item_id    dept_id   cat_id  \
# 0         HOBBIES_1_008_CA_1_evaluation  HOBBIES_1_008  HOBBIES_1  HOBBIES
# 1         HOBBIES_1_009_CA_1_evaluation  HOBBIES_1_009  HOBBIES_1  HOBBIES
# 2         HOBBIES_1_010_CA_1_evaluation  HOBBIES_1_010  HOBBIES_1  HOBBIES
# 3         HOBBIES_1_012_CA_1_evaluation  HOBBIES_1_012  HOBBIES_1  HOBBIES
# 4         HOBBIES_1_015_CA_1_evaluation  HOBBIES_1_015  HOBBIES_1  HOBBIES
# ...                                 ...            ...        ...      ...
# 47735392    FOODS_3_823_WI_3_evaluation    FOODS_3_823    FOODS_3    FOODS
# 47735393    FOODS_3_824_WI_3_evaluation    FOODS_3_824    FOODS_3    FOODS
# 47735394    FOODS_3_825_WI_3_evaluation    FOODS_3_825    FOODS_3    FOODS
# 47735395    FOODS_3_826_WI_3_evaluation    FOODS_3_826    FOODS_3    FOODS
# 47735396    FOODS_3_827_WI_3_evaluation    FOODS_3_827    FOODS_3    FOODS
#
#          store_id state_id     d  sales  release
# ...

# %%
pd.read_pickle('processed_data/grid_part_2_eval.pkl')
# Out:
#                                      id       d  sell_price  price_max  \
# 0         HOBBIES_1_008_CA_1_evaluation     d_1    0.459961   0.500000
# 1         HOBBIES_1_009_CA_1_evaluation     d_1    1.559570   1.769531
# 2         HOBBIES_1_010_CA_1_evaluation     d_1    3.169922   3.169922
# 3         HOBBIES_1_012_CA_1_evaluation     d_1    5.980469   6.519531
# 4         HOBBIES_1_015_CA_1_evaluation     d_1    0.700195   0.720215
# ...                                 ...     ...         ...        ...
# 47735392    FOODS_3_823_WI_3_evaluation  d_1969    2.980469   2.980469
# 47735393    FOODS_3_824_WI_3_evaluation  d_1969    2.480469   2.679688
# 47735394    FOODS_3_825_WI_3_evaluation  d_1969    3.980469   4.378906
# 47735395    FOODS_3_826_WI_3_evaluation  d_1969    1.280273   1.280273
# 47735396    FOODS_3_827_WI_3_evaluation  d_1969    1.000000   1.000000
#
#           price_min  price_std  price_mean  price_norm  price_nunique  \
# ...

# %%
pd.read_pickle('processed_data/grid_part_3_eval.pkl')
# Out:
#                                      id       d  event_name_1 event_type_1  \
# 0         HOBBIES_1_008_CA_1_evaluation     d_1           NaN          NaN
# 1         HOBBIES_1_009_CA_1_evaluation     d_1           NaN          NaN
# 2         HOBBIES_1_010_CA_1_evaluation     d_1           NaN          NaN
# 3         HOBBIES_1_012_CA_1_evaluation     d_1           NaN          NaN
# 4         HOBBIES_1_015_CA_1_evaluation     d_1           NaN          NaN
# ...                                 ...     ...           ...          ...
# 47735392    FOODS_3_823_WI_3_evaluation  d_1969  NBAFinalsEnd     Sporting
# 47735393    FOODS_3_824_WI_3_evaluation  d_1969  NBAFinalsEnd     Sporting
# 47735394    FOODS_3_825_WI_3_evaluation  d_1969  NBAFinalsEnd     Sporting
# 47735395    FOODS_3_826_WI_3_evaluation  d_1969  NBAFinalsEnd     Sporting
# 47735396    FOODS_3_827_WI_3_evaluation  d_1969  NBAFinalsEnd     Sporting
#
# ...

# %%
pd.read_pickle('processed_data/lags_df_28_eval.pkl')
# Out:
#                                      id     d  sales  sales_lag_28  \
# 0         HOBBIES_1_008_CA_1_evaluation     1   12.0           NaN
# 1         HOBBIES_1_009_CA_1_evaluation     1    2.0           NaN
# 2         HOBBIES_1_010_CA_1_evaluation     1    0.0           NaN
# 3         HOBBIES_1_012_CA_1_evaluation     1    0.0           NaN
# 4         HOBBIES_1_015_CA_1_evaluation     1    4.0           NaN
# ...                                 ...   ...    ...           ...
# 47735392    FOODS_3_823_WI_3_evaluation  1969    NaN           1.0
# 47735393    FOODS_3_824_WI_3_evaluation  1969    NaN           0.0
# 47735394    FOODS_3_825_WI_3_evaluation  1969    NaN           2.0
# 47735395    FOODS_3_826_WI_3_evaluation  1969    NaN           0.0
# 47735396    FOODS_3_827_WI_3_evaluation  1969    NaN           1.0
#
#           sales_lag_29  sales_lag_30  sales_lag_31  sales_lag_32  \
# 0                  NaN           NaN           NaN           NaN
# ...

# %%
pd.read_pickle('processed_data/mean_encoding_df_eval.pkl')
# Out:
#                                      id     d  enc_state_id_mean  \
# 0         HOBBIES_1_008_CA_1_evaluation     1           1.576172
# 1         HOBBIES_1_009_CA_1_evaluation     1           1.576172
# 2         HOBBIES_1_010_CA_1_evaluation     1           1.576172
# 3         HOBBIES_1_012_CA_1_evaluation     1           1.576172
# 4         HOBBIES_1_015_CA_1_evaluation     1           1.576172
# ...                                 ...   ...                ...
# 47735392    FOODS_3_823_WI_3_evaluation  1969           1.318359
# 47735393    FOODS_3_824_WI_3_evaluation  1969           1.318359
# 47735394    FOODS_3_825_WI_3_evaluation  1969           1.318359
# 47735395    FOODS_3_826_WI_3_evaluation  1969           1.318359
# 47735396    FOODS_3_827_WI_3_evaluation  1969           1.318359
#
#           enc_state_id_std  enc_store_id_mean  enc_store_id_std  \
# 0                 4.605469           1.639648          4.476562
# ...
